# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('banking_data.csv')
df.head()
# Out:
#    age           job  marital marital_status  education default  balance  \
# 0   58    management  married        married   tertiary      no     2143
# 1   44    technician   single         single  secondary      no       29
# 2   33  entrepreneur  married        married  secondary      no        2
# 3   47   blue-collar  married        married    unknown      no     1506
# 4   33       unknown   single         single    unknown      no        1
#
#   housing loan  contact  day month day_month  duration  campaign  pdays  \
# 0     yes   no  unknown    5   may     5-May       261         1     -1
# 1     yes   no  unknown    5   may     5-May       151         1     -1
# 2     yes  yes  unknown    5   may     5-May        76         1     -1
# 3     yes   no  unknown    5   may     5-May        92         1     -1
# 4      no   no  unknown    5   may     5-May       198         1     -1
#
#    previous poutcome   y
# 0         0  unknown  no
# 1         0  unknown  no
# ...

# %%
df.isnull().sum() # checking for missing data
# Out:
# age               0
# job               0
# marital           3
# marital_status    3
# education         3
# default           0
# balance           0
# housing           0
# loan              0
# contact           0
# day               0
# month             0
# day_month         0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# y                 0
# dtype: int64

# %%
df[df['marital_status'].isnull()]
# Out:
#        age          job marital marital_status  education default  balance  \
# 44996   75      retired     NaN            NaN  secondary      no     1092
# 45077   20      student     NaN            NaN  secondary      no       88
# 45209   57  blue-collar     NaN            NaN  secondary      no      668
#
#       housing loan    contact  day month day_month  duration  campaign  pdays  \
# 44996      no   no  telephone   12   oct    12-Oct       250         1    431
# 45077      no   no  telephone   21   oct    21-Oct       621         1    181
# 45209      no   no  telephone   17   nov    17-Nov       508         4     -1
#
#        previous poutcome   y
# 44996         2  failure  no
# 45077         4    other  no
# 45209         0  unknown  no

# %%
df[df['education'].isnull()]
# Out:
#        age         job marital marital_status education default  balance  \
# 44957   32  management  single         single       NaN      no     3289
# 45137   30  management  single         single       NaN      no      297
# 45170   19     student  single         single       NaN      no      245
#
#       housing loan    contact  day month day_month  duration  campaign  pdays  \
# 44957      no   no   cellular    8   oct     8-Oct       375         2    179
# 45137      no   no   cellular    8   nov     8-Nov       188         1     -1
# 45170      no   no  telephone   10   nov    10-Nov        98         2    110
#
#        previous poutcome    y
# 44957         2  failure   no
# 45137         0  unknown  yes
# 45170         2    other   no

# %% [markdown]
# # **Distribution of Age**

# %%
df['age'].describe()
# Out:
# count    45216.000000
# mean        40.938186
# std         10.621249
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
plt.figure(dpi=200)
sns.histplot(df['age'],kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # **Job type variation**

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9460
# technician       7597
# admin.           5171
# services         4154
# retired          2267
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
plt.figure(dpi=200)
sns.countplot(df,x='job')
plt.xticks(rotation=90)
None

# %%
sns.barplot(data=df,x='job',y='age',estimator=np.mean,errorbar='sd')
plt.xticks(rotation=90)
None

# %% [markdown]
# # **Marital Status distribution**

# %%
df['marital_status'].describe()
# Out:
# count       45213
# unique          3
# top       married
# freq        27216
# Name: marital_status, dtype: object

# %%
df[df['marital_status'].isnull()]
# Out:
#        age          job marital marital_status  education default  balance  \
# 44996   75      retired     NaN            NaN  secondary      no     1092
# 45077   20      student     NaN            NaN  secondary      no       88
# 45209   57  blue-collar     NaN            NaN  secondary      no      668
#
#       housing loan    contact  day month day_month  duration  campaign  pdays  \
# 44996      no   no  telephone   12   oct    12-Oct       250         1    431
# 45077      no   no  telephone   21   oct    21-Oct       621         1    181
# 45209      no   no  telephone   17   nov    17-Nov       508         4     -1
#
#        previous poutcome   y
# 44996         2  failure  no
# 45077         4    other  no
# 45209         0  unknown  no

# %%
df['marital_status']=df['marital_status'].fillna('single')

# %%
plt.figure(dpi=200)
sns.countplot(df,x='marital_status')
# Out:
# <Axes: xlabel='marital_status', ylabel='count'>

# %% [markdown]
# # **Level of education**

# %%
df['education'].describe()
# Out:
# count         45213
# unique            4
# top       secondary
# freq          23204
# Name: education, dtype: object

# %%
df[df['education'].isnull()]
# Out:
#        age         job marital marital_status education default  balance  \
# 44957   32  management  single         single       NaN      no     3289
# 45137   30  management  single         single       NaN      no      297
# 45170   19     student  single         single       NaN      no      245
#
#       housing loan    contact  day month day_month  duration  campaign  pdays  \
# 44957      no   no   cellular    8   oct     8-Oct       375         2    179
# 45137      no   no   cellular    8   nov     8-Nov       188         1     -1
# 45170      no   no  telephone   10   nov    10-Nov        98         2    110
#
#        previous poutcome    y
# 44957         2  failure   no
# 45137         0  unknown  yes
# 45170         2    other   no

# %%
df['education']=df['education'].fillna('unknown')  # filling the missing data with unknown can be considered as a way to fill values

# %%
plt.figure(dpi=200)
sns.countplot(df,x='education')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
plt.figure(dpi=200)
sns.barplot(df,x='education',y='age')
# Out:
# <Axes: xlabel='education', ylabel='age'>

# %% [markdown]
# # **Credit**

# %%
df['default'].value_counts()
# Out:
# default
# no     44401
# yes      815
# Name: count, dtype: int64

# %%
#Proportion ratio
len(df[df['default']=='yes'])/len(df),len(df[df['default']=='no'])/len(df)
# Out:
# (0.018024593064401982, 0.981975406935598)

# %%
df['default'].value_counts(normalize=True).plot(kind='bar')
plt.title('Proportion of Clients with Credit in Default')
plt.xlabel('Default')
plt.ylabel('Proportion')
# Out:
# Text(0, 0.5, 'Proportion')

# %% [markdown]
# # **Distribution of Average Yearly Balance**

# %%
modified_balance=df['balance']/1000
df['balance']=modified_balance
df['balance'].describe()
# Out:
# count    45216.000000
# mean         1.362278
# std          3.044610
# min         -8.019000
# 25%          0.072000
# 50%          0.448500
# 75%          1.428000
# max        102.127000
# Name: balance, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['balance'], bins=100, kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='balance', ylabel='Count'>

# %% [markdown]
# # **Housing loans**

# %%
df['housing'].value_counts()
# Out:
# housing
# yes    25130
# no     20086
# Name: count, dtype: int64

# %%
df['housing'].value_counts(normalize=True).plot(kind='bar')
plt.title('Clients with Housing Loans')
plt.xlabel('Housing Loan')
plt.ylabel('Proportion')
None

# %% [markdown]
# # **Personal Loans**

# %%
df['loan'].value_counts()
# Out:
# loan
# no     37972
# yes     7244
# Name: count, dtype: int64

# %%
df['loan'].value_counts(normalize=True).plot(kind='bar')
plt.title('Clients with Personal Loans')
plt.xlabel('Personal Loan')
plt.ylabel('Proportion')
None

# %% [markdown]
# # **Communication Types for contacting clients**

# %%
df['contact'].value_counts()
# Out:
# contact
# cellular     29290
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %%
plt.figure(dpi=200)
sns.countplot(df,x='contact')
None

# %% [markdown]
# # **Last contact day of the month**

# %%
df['day'].value_counts()
# Out:
# day
# 20    2752
# 18    2308
# 21    2026
# 17    1942
# 6     1932
# 5     1910
# 14    1848
# 8     1842
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1479
# 4     1445
# 16    1417
# 2     1293
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: count, dtype: int64

# %%
plt.figure(dpi=200)
sns.histplot(df,x='day')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='Count'>

# %% [markdown]
# # **Last contact month**

# %%
df['month'].describe()
# Out:
# count     45216
# unique       12
# top         may
# freq      13766
# Name: month, dtype: object

# %%
sns.countplot(y='month', data=df, order=df['month'].value_counts().index)
plt.title('Last Contact Month Distribution')
plt.xlabel('Count')
plt.ylabel('Month')
None

# %% [markdown]
# # **Last contact duration**

# %%
df['duration'].describe()
# Out:
# count    45216.000000
# mean       258.166202
# std        257.515482
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
plt.figure(dpi=200)
sns.histplot(df,x='duration',bins=500,kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# # **Contacts performed during campaign**

# %%
df['campaign'].describe()
# Out:
# count    45216.000000
# mean         2.763668
# std          3.097896
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         63.000000
# Name: campaign, dtype: float64

# %%
plt.figure(dpi=200,figsize=(12,8))
sns.countplot(df,x='campaign')
None

# %% [markdown]
# # **Number of days passed since the client was last contacted from a previous campaign**

# %%
df['pdays'].describe()
# Out:
# count    45216.000000
# mean        40.202428
# std        100.128248
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
df['pdays'].value_counts()
# Out:
# pdays
# -1      36956
#  182      167
#  92       147
#  91       126
#  183      126
#         ...
#  32         1
#  551        1
#  670        1
#  65         1
#  530        1
# Name: count, Length: 559, dtype: int64

# %%
plt.figure(dpi=200,figsize=(10,8))
sns.histplot(df,x='pdays',bins=50,kde=True)
None
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # **Contacts performed before the current campaign**

# %%
df['previous'].describe()
# Out:
# count    45216.000000
# mean         0.580657
# std          2.303778
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        275.000000
# Name: previous, dtype: float64

# %%
plt.figure(dpi=200,figsize=(10,6))
sns.countplot(df,y='previous')
None

# %% [markdown]
# # **Outcomes of previous marketing campaigns**

# %%
df['poutcome'].value_counts()
# Out:
# poutcome
# unknown    36961
# failure     4902
# other       1840
# success     1513
# Name: count, dtype: int64

# %%
plt.figure(dpi=200)
sns.countplot(df,x='poutcome')
None

# %% [markdown]
# # **Distribution of clients who subscribed to a term deposit vs. those who did not**

# %%
df['y'].value_counts()
# Out:
# y
# no     39922
# yes     5294
# Name: count, dtype: int64

# %%
plt.figure(dpi=200,figsize=(3,2))
sns.countplot(df,x='y')
plt.xlabel('reponse')
None

# %% [markdown]
# # **Correlations between different attributes and the likelihood of subscribing to a term deposit**

# %%
df.head()
# Out:
#    age           job  marital marital_status  education default  balance  \
# 0   58    management  married        married   tertiary      no    2.143
# 1   44    technician   single         single  secondary      no    0.029
# 2   33  entrepreneur  married        married  secondary      no    0.002
# 3   47   blue-collar  married        married    unknown      no    1.506
# 4   33       unknown   single         single    unknown      no    0.001
#
#   housing loan  contact  day month day_month  duration  campaign  pdays  \
# 0     yes   no  unknown    5   may     5-May       261         1     -1
# 1     yes   no  unknown    5   may     5-May       151         1     -1
# 2     yes  yes  unknown    5   may     5-May        76         1     -1
# 3     yes   no  unknown    5   may     5-May        92         1     -1
# 4      no   no  unknown    5   may     5-May       198         1     -1
#
#    previous poutcome   y
# 0         0  unknown  no
# 1         0  unknown  no
# ...

# %%
df_nums=df.select_dtypes(exclude='object')
df_objs=df[['default','housing','loan','y']].copy()

# %%
df_objs=pd.get_dummies(df_objs,drop_first=True)
final_df=pd.concat([df_nums,df_objs],axis=1)
final_df
# Out:
#        age  balance  day  duration  campaign  pdays  previous  default_yes  \
# 0       58    2.143    5       261         1     -1         0        False
# 1       44    0.029    5       151         1     -1         0        False
# 2       33    0.002    5        76         1     -1         0        False
# 3       47    1.506    5        92         1     -1         0        False
# 4       33    0.001    5       198         1     -1         0        False
# ...    ...      ...  ...       ...       ...    ...       ...          ...
# 45211   29    0.765   16       238         1     -1         0        False
# 45212   68    1.146   16       212         1    187         6        False
# 45213   53    0.583   17       226         1    184         4        False
# 45214   73    2.850   17       300         1     40         8        False
# 45215   71    1.729   17       456         2     -1         0        False
#
#        housing_yes  loan_yes  y_yes
# ...

# %%
final_df.corr()['y_yes'].sort_values()
# Out:
# housing_yes   -0.139445
# campaign      -0.073294
# loan_yes      -0.068289
# day           -0.028307
# default_yes   -0.022451
# age            0.025648
# balance        0.052821
# previous       0.093576
# pdays          0.103699
# duration       0.394387
# y_yes          1.000000
# Name: y_yes, dtype: float64

# %%
sns.heatmap(final_df.corr())
# Out:
# <Axes: >
